# %% [markdown]
# ## Baseline Submission: Toxic Language Classification
# **w207 Spring 2018 - Final Project Baseline**
#
# **Team: Paul, Walt, Yisang, Joe**
#
#
#
# ### Project Description
#
# Our challenge is to build a multi-headed model that’s capable of detecting different types of of toxicity like threats, obscenity, insults, and identity-based hate.  The toxic language data set is sourced from Wikipedia and available as a public kaggle data set.
#
# Our goal is to use various machine learning techniques used in class to develop high quality ML models and pipelines.
#
# 1. Exercise and build upon concepts covered in class and test out at least 3 kinds of supervised models:
#     a. Regression (LASSO, Logistic)
#     b. Trees (RF, XGBoost)
#     c. DeepLearning (Tensorflow)
# 2. Using stacking/ensembling methods for improving prediction metrics (K-Means, anomaly detection)
# 3. Using unsupervised methods for feature engineering/selection
#
# For the baseline proposal, this file contains a first pass run through from data preprocessing to model evaluation using a regression model pipeline.
#
# https://www.kaggle.com/c/jigsaw-toxic-comment-classification-challenge

# %% [markdown]
# ### Data Ingestion
#
# Our team ingested the Toxic Comments data set and applied custom partitions for internal development and testing.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

#sklearn imports
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.grid_search import GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer

#scipy imports
from scipy.sparse import hstack

#Visualization imports
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec 
import bokeh
#! pip install bokeh

# target classes
target_names = ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %%
# read frames localy through csv
train_df = pd.read_csv("../w207_FinalProject-master3/data/train.csv")
test_df = pd.read_csv("../w207_FinalProject-master3/data/test.csv")

# Random index generator for splitting training data
# Note: Each rerun of cell will create new splits.
randIndexCut = np.random.rand(len(train_df)) < 0.7

#S plit up data
test_data = test_df["comment_text"]
dev_data, dev_labels = train_df[~randIndexCut]["comment_text"], train_df[~randIndexCut][target_names]
train_data, train_labels = train_df[randIndexCut]["comment_text"], train_df[randIndexCut][target_names]

print 'total training observations:', train_df.shape[0]
print 'training data shape:', train_data.shape
print 'training label shape:', train_labels.shape
print 'dev label shape:', dev_labels.shape
print 'labels names:', target_names
# Out:
# total training observations: 159571
# training data shape: (111600,)
# training label shape: (111600, 6)
# dev label shape: (47971, 6)
# labels names: ['toxic', 'severe_toxic', 'obscene', 'threat', 'insult', 'identity_hate']

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Class Imbalance

# %% [markdown]
# Let's see how imblanced the label set is in order to have a better understanding with the label quality of the given data set.

# %%
from bokeh.io import push_notebook
from bokeh.plotting import figure, show, output_file, output_notebook

target_counts = train_labels.apply(np.sum,0)
target_counts

output_notebook()

p = figure(x_range=target_names)
p.vbar(x=target_names, top = target_counts, width=0.9)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="81209d56-2240-477b-b508-1e674e303ebe">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c5466f2c-34c1-4c32-84cb-29fb470c8bff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c5466f2c-34c1-4c32-84cb-29fb470c8bff").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c5466f2c-34c1-4c32-84cb-29fb470c8bff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c5466f2c-34c1-4c32-84cb-29fb470c8bff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b08e10a8-4aa8-48f6-9f5e-2578187e5102":{"roots":{"references":[{"attributes":{"callback":null},"id":"cfcd2acb-412e-455c-8220-f9eb7afbaf73","type":"DataRange1d"},{"attributes":{"overlay":{"id":"4f1b5d90-7265-4f36-87ae-1effd81c1070","type":"BoxAnnotation"},"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"}},"id":"42f2d064-a618-42a6-893f-86733d5307dd","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"95610088-8014-4ba5-b35d-2c3ee25a037d","type":"ColumnDataSource"},"glyph":{"id":"7690968c-60a8-4eb0-9ae9-c487bc5a5372","type":"VBar"},"hover_glyph":null,"nonselection_glyph":{"id":"390a5577-565c-4afd-b0ed-6680f1686ae4","type":"VBar"},"selection_glyph":null},"id":"aab7a3d5-fa54-4d8e-8731-12e5dde1b414","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"4516c8b0-19d2-4b46-b988-e45b2da7e9c4","type":"BasicTickFormatter"},"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d0630e8-e38b-436b-8633-898dd147aca3","type":"BasicTicker"}},"id":"e6356e62-fb5a-419d-b65f-7423ccb15d78","type":"LinearAxis"},{"attributes":{"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"}},"id":"c4527acf-e2c5-40b2-8e00-e7133ebafc92","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"}},"id":"1e7f9a3c-2677-4022-a0ed-60c1233b3207","type":"ResetTool"},{"attributes":{"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"}},"id":"dcc06a0f-c296-452c-924e-89d42132ed52","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4f1b5d90-7265-4f36-87ae-1effd81c1070","type":"BoxAnnotation"},{"attributes":{"callback":null,"factors":["toxic","severe_toxic","obscene","threat","insult","identity_hate"]},"id":"9e0832a6-7fc0-457d-a9c3-d7fb481d99cc","type":"FactorRange"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"390a5577-565c-4afd-b0ed-6680f1686ae4","type":"VBar"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"0515e3df-851f-401c-884b-7ed5681fe6d8","type":"PanTool"},{"id":"c4527acf-e2c5-40b2-8e00-e7133ebafc92","type":"WheelZoomTool"},{"id":"42f2d064-a618-42a6-893f-86733d5307dd","type":"BoxZoomTool"},{"id":"fc7ab861-b4dc-4364-9e39-a95b524c387e","type":"SaveTool"},{"id":"1e7f9a3c-2677-4022-a0ed-60c1233b3207","type":"ResetTool"},{"id":"dcc06a0f-c296-452c-924e-89d42132ed52","type":"HelpTool"}]},"id":"04064a47-2120-4bf8-b82b-37e7b565235f","type":"Toolbar"},{"attributes":{},"id":"4516c8b0-19d2-4b46-b988-e45b2da7e9c4","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"},"ticker":{"id":"2d0630e8-e38b-436b-8633-898dd147aca3","type":"BasicTicker"}},"id":"c4f2be66-a282-4187-93f0-de84afba0114","type":"Grid"},{"attributes":{"plot":{"id":"f6468ca6-d0df-4aca-b677-4740ac7c7dcc","subtype":"Figure","type":"Plot"},"ticker":{"id":"01fd0187-9b97-43fc-8553-69d0201c7dae","type":"CategoricalTicker"}},"id":"d27c3768-25c9-46c2-9920-2eb738445b4e","type":"Grid"},{"attributes":{},"id":"01fd0187-9b97-43fc-8553-69d0201c7dae","type":"CategoricalTicker"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.9},"x":{"field":"x"}},"id":"7690968c-60a8-4eb0-9ae9-c487bc5a5372","type":"VBar"},{"attributes":{"formatter":{"id":"0fe16360-18bd-48a0-acdb-6c5f2bb8d65a","type":"CategoricalTickFormatter"},"plot":{"id":"f6468ca6-d ...

# %% [markdown]
# The data is fairly imbalanced when counting label occurrences.

# %% [markdown]
# Ideas to consider
# - Sampling methods
# - Custom Cross Validation

# %% [markdown]
# #### Word Length Distribution

# %%
from bokeh.charts import Histogram
import numpy as np
from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
from collections import Counter

s = " ".join(list(train_data))
split_words = s.split()
word_dist = [len(x) for x in split_words]
word_hist = Counter(word_dist)

p1 = figure(title="Word Distribution",tools="save")

hist, edges = np.histogram(word_dist, density=True, bins = 10000)

p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

p1.legend.location = "center_right"
p1.legend.background_fill_color = "darkgrey"
p1.xaxis.axis_label = 'Anonymized Word Length'
p1.yaxis.axis_label = 'Percent of Total Frequency'

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9628af77-9a89-41fa-a211-7d12433083b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9628af77-9a89-41fa-a211-7d12433083b4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9628af77-9a89-41fa-a211-7d12433083b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9628af77-9a89-41fa-a211-7d12433083b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f7e22d1c-4454-4c8b-b4bd-34bcc9e1f4e7":{"roots":{"references":[{"attributes":{"callback":null},"id":"424d9b8a-b17d-48ea-a20a-c2293c9f8f0c","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"0c698e18-8e72-4547-8542-11cbd77625c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"747078e9-02de-4fd2-a56e-a52d36a6b8d9","type":"BasicTicker"}},"id":"d1e72604-0d65-45f6-b8c9-51fb4cbd6689","type":"Grid"},{"attributes":{"plot":null,"text":"Word Distribution"},"id":"ac9ce943-189d-4988-9cf1-16776ddf82ba","type":"Title"},{"attributes":{"callback":null},"id":"4ec71ba2-fe78-4394-a62c-403e1840a0af","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f534fee4-f88e-44fd-a14c-a3e08d19b817","type":"SaveTool"}]},"id":"60c316aa-b0f1-4dad-b38d-c6e5d5a6ecc2","type":"Toolbar"},{"attributes":{},"id":"ef270252-414f-4821-b347-cd66dfea40a3","type":"ToolEvents"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2d3d26b1-67e4-4e24-a6fd-18c1331667da","type":"Quad"},{"attributes":{"data_source":{"id":"07558f6b-c8c4-4da0-80f3-f0f0f58b8e04","type":"ColumnDataSource"},"glyph":{"id":"2d3d26b1-67e4-4e24-a6fd-18c1331667da","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"05a6ddea-0529-4f5a-9a9b-1da79612094e","type":"Quad"},"selection_glyph":null},"id":"df82aa9c-5914-4af6-a367-adc145338554","type":"GlyphRenderer"},{"attributes":{"axis_label":"Anonymized Word Length","formatter":{"id":"289ba1bd-aa57-4e94-bd94-02a98366279d","type":"BasicTickFormatter"},"plot":{"id":"0c698e18-8e72-4547-8542-11cbd77625c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"d88e0301-1097-4015-86d6-0260df781869","type":"BasicTicker"}},"id":"583a9b13-177c-4b1a-bdc7-8eeeafedd357","type":"LinearAxis"},{"attributes":{"below":[{"id":"583a9b13-177c-4b1a-bdc7-8eeeafedd357","type":"LinearAxis"}],"left":[{"id":"7f4ada24-a230-4a91-b8fc-f50bd6085ef0","type":"LinearAxis"}],"renderers":[{"id":"583a9b13-177c-4b1a-bdc7-8eeeafedd357","type":"LinearAxis"},{"id":"7c76b159-dc49-4cbb-add7-56b8ce365686","type":"Grid"},{"id":"7f4ada24-a230-4a91-b8fc-f50bd6085ef0","type":"LinearAxis"},{"id":"d1e72604-0d65-45f6-b8c9-51fb4cbd6689","type":"Grid"},{"id":"df82aa9c-5914-4af6-a367-adc145338554","type":"GlyphRenderer"}],"title":{"id":"ac9ce943-189d-4988-9cf1-16776ddf82ba","type":"Title"},"tool_events":{"id":"ef270252-414f-4821-b347-cd66dfea40a3","type":"ToolEvents"},"toolbar":{"id":"60c316aa-b0f1-4dad-b38d-c6e5d5a6ecc2","type":"Toolbar"},"x_range":{"id":"4ec71ba2-fe78-4394-a62c-403e1840a0af","type":"DataRange1d"},"y_range":{"id":"424d9b8a-b17d-48ea-a20a-c2293c9f8f0c","type":"DataRange1d"}},"id":"0c698e18-8e72-4547-8542-11cbd77625c1","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"05a6ddea-0529-4f5a-9a9b-1da79612094e","type":"Quad"},{"attributes":{"plot":{"id":"0c698e18-8e72-4547-8542-11cbd77625c1","subtype":"Figure","type":"Plot"}},"id":"f534fee4-f88e-44fd-a14c-a3e08d19b817","type":"SaveTool"},{"attributes":{},"id":"d88e0301-1097-4015-86d6-0260df781869","type":"BasicTicker"},{"attributes":{"axis_label":"Percent of Total Frequency","formatter":{"id":"b5392a5b-bce5-4879-8111-59351f69dac0","type":"BasicTickFormatter"},"plot":{"id":"0c698e18-8e72-4547-8542-11cbd77625c1","subtype":"Figure","type":"Plot"},"ticker":{"id":"747078e9-02de-4fd2-a56e-a52d36a6b8d9","type":"BasicTicker"}},"id":"7f4ada24-a230-4a91-b8fc-f50bd6085ef0","type":"LinearAxis"},{"attributes":{},"id":"b5392a5b-bce5-4879-8111-59351f69dac0","type":"BasicTickFormatter"},{"attributes":{},"id":"289ba1bd-aa57-4e94-bd94-02a98366279d","type":"BasicTickFormatter"},{"attributes":{},"id":"747078e9-02de-4fd2-a ...

# %% [markdown]
# We can see that there are invalid words that have a high length.  The text comments contains messages in different languages as well as non-english characters which would explain the existance of words of signficant length.

# %%
print([i in train_data])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-0fa7060d1958> in <module>()
# ----> 1 print([i in train_data])
#
# NameError: name 'i' is not defined

# %% [markdown]
# ### Feature Engineering/Selection (WIP)
# ....

# %% [markdown]
# ### Modeling

# %% [markdown]
# #### Text Processing

# %%
# Basic Count Vectorizer
countVector = CountVectorizer(ngram_range=(1,1))
train_counts = countVector.fit_transform(train_data)

print("Vocabulary size is: {}").format(len(countVector.vocabulary_))

print("Number of nonzero entries in matrix: {}").format(train_counts.nnz)

#sample column wise sum, we can see that an observation can have multiple classes. 
count_df = pd.DataFrame(train_labels.apply(np.sum,1), columns = ["counts"])
count_df = count_df[((count_df["counts"] >= 1))]
count_df.head(10)
# Out:
# Vocabulary size is: 152776
# Number of nonzero entries in matrix: 4864565
#     counts
# 6        4
# 43       3
# 44       1
# 51       2
# 55       4
# 56       3
# 58       2
# 59       1
# 79       2
# 86       2

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.metrics import auc
# SK-learn libraries for cross validation
from sklearn.cross_validation import StratifiedKFold, cross_val_score, train_test_split 
# Basic Logistic Regression Model/MultiLabel Edition

prediction_output = []
scores_output = []
for name in target_names:
    classifier = LogisticRegression(solver='sag') 
    cv_score = np.mean(cross_val_score(
        classifier, train_counts, train_labels[name], cv=3, scoring='roc_auc'))
    scores_output.append(cv_score)
    print('CV score for class {} is {}'.format(name, cv_score))
    classifier.fit(train_counts, train_labels[name])
    
    
print("Mean ROC_AUC: {}").format(np.mean(scores_output))
# Out:
# /Users/jolee/anaconda/envs/py27/lib/python2.7/site-packages/sklearn/linear_model/sag.py:267: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# CV score for class toxic is 0.792035661105
# CV score for class severe_toxic is 0.775500416549
# CV score for class obscene is 0.76952280193
# CV score for class threat is 0.634613216981
# CV score for class insult is 0.770025214714
# CV score for class identity_hate is 0.676147422434
# Mean ROC_AUC: 0.736307455619

# %% [markdown]
# #### Testing on Dev Data

# %%
from sklearn.metrics import auc, roc_curve
from sklearn import metrics

dev_Vector = CountVectorizer(ngram_range=(1,1))
dev_counts = countVector.fit_transform(dev_data)

pred_dt = pd.DataFrame()
scores_dev = []
for name in target_names:
    classifier = LogisticRegression(solver='sag') 
    classifier.fit(dev_counts, dev_labels[name])
    scores_dev.append(cv_score)
    output = classifier.predict(dev_counts)
    fpr, tpr, thresholds = metrics.roc_curve(dev_labels[name], output)
    print('Dev score for class {} is {}'.format(name, metrics.auc(fpr,tpr)))
    pred_dt[name] = classifier.predict_proba(dev_counts)[:, 1]
    
    
print("Mean(dev) ROC_AUC: {}").format(np.mean(scores_dev))
# Out:
# Dev score for class toxic is 0.675413012295
# Dev score for class severe_toxic is 0.581701390358
# Dev score for class obscene is 0.631987934387
# Dev score for class threat is 0.503865476473
# Dev score for class insult is 0.60758283931
# Dev score for class identity_hate is 0.521895703782
# Mean(dev) ROC_AUC: 0.676147422434

# %% [markdown]
# Score on dev set is worse than training set, thus evidence of overfitting and a need for performance improvement.

# %% [markdown]
# The target is multi-label since each observation can be classified as multiple fields.  This is an important distinction from multi-class where each prediction can only be one label.

# %% [markdown]
# ## Evaluation

# %%
count_df
train_labels["toxic"]
# Out:
# 0         0
# 1         0
# 2         0
# 5         0
# 6         1
# 9         0
# 10        0
# 11        0
# 13        0
# 14        0
# 17        0
# 18        0
# 21        0
# 22        0
# 24        0
# 25        0
# 26        0
# 27        0
# 29        0
# 30        0
# 31        0
# 32        0
# 35        0
# 36        0
# 38        0
# 39        0
# 41        0
# 43        1
# 44        1
# 46        0
#          ..
# 159535    0
# 159536    0
# 159537    0
# 159538    0
# 159539    0
# 159540    0
# 159541    1
# 159542    0
# 159544    0
# 159545    0
# 159546    1
# 159547    0
# 159549    0
# 159550    0
# 159551    0
# 159554    1
# 159555    0
# 159557    0
# 159558    0
# 159559    0
# 159560    0
# 159561    0
# 159562    0
# 159563    0
# 159564    0
# 159565    0
# 159566    0
# 159567    0
# 159569    0
# 159570    0
# Name: toxic, dtype: int64

# %% [markdown]
# ### Submission

# %%
from sklearn.metrics import auc
# SK-learn libraries for cross validation
from sklearn.cross_validation import StratifiedKFold, cross_val_score, train_test_split 
# Basic Logistic Regression Model/MultiLabel Edition

prediction_submission = pd.DataFrame()
prediction_submission["id"] = test_df["id"]

# new vector object for all train data for submission
finalTrainVector = CountVectorizer()
finalTrainCount = finalTrainVector.fit_transform(train_df["comment_text"])

# TODO: Using pipelines can clean up repeitive processes
# test set up
#testVector = CountVectorizer()
testCount = finalTrainVector.transform(test_df["comment_text"])

for name in target_names:
    classifier = LogisticRegression(solver='sag') #sag is one kind of solver optimize for multi-label
    clf = classifier.fit(finalTrainCount, train_df["toxic"])
    prediction_submission[name] = clf.predict_proba(testCount)[:, 1]
    #print(prediction_submission)

    
print(prediction_submission.head(10)) # print frame output 
#prediction_submission.to_csv("submission.csv")
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.889472      0.889208  0.889490  0.889300  0.889859
# 1  0000247867823ef7  0.250917      0.250663  0.250762  0.250821  0.250742
# 2  00013b17ad220c46  0.432613      0.432735  0.432661  0.432668  0.432595
# 3  00017563c3f7919a  0.068362      0.068237  0.068175  0.068064  0.068163
# 4  00017695ad8997eb  0.424004      0.424707  0.424460  0.424676  0.424557
# 5  0001ea8717f6de06  0.340763      0.340854  0.340989  0.340558  0.340962
# 6  00024115d4cbde0f  0.124536      0.124778  0.124653  0.124630  0.124505
# 7  000247e83dcc1211  0.452367      0.452056  0.452069  0.452164  0.452073
# 8  00025358d4737918  0.006227      0.006221  0.006210  0.006212  0.006193
# 9  00026d1092fe71cc  0.044093      0.044136  0.044161  0.044094  0.044203
#
#    identity_hate
# 0       0.888301
# 1       0.250729
# 2       0.432661
# 3       0.068241
# 4       0.424652
# 5       0.340869
# 6       0.124839
# 7       0.452120
# 8       0.006195
# 9       0.044119

# %% [markdown]
# The frame contains the output for each class and is saved in a pandas data frame.

# %%
# Out:
# Collecting deepwater
#   Could not find a version that satisfies the requirement deepwater (from versions: )
# No matching distribution found for deepwater
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
